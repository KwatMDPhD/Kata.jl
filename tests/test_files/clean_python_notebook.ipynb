# %%
print("This is a test notebook.")

# %%
def f(
    alpha,
    beta,
    gamma,
    delta,
    epsilon,
    zeta,
    eta,
    theta,
    iota,
    kappa,
    mu,
    nu,
    xi,
    omicron,
):
    return 1
