# %% [markdown]
# # Sort import

# %%
import os
import sys

import numpy as np
import pandas as pd

# %% [markdown]
# # Keep comment

# %%
# Comment

# %% [markdown]
# # Keep quote

# %%
""

""

"abc"

"ab'c'"

'ab"c"'

"""abc"""

"""abc"""

"'"

'"'

"""
'abc'
"""

"""
"abc"
"""

# %% [markdown]
# # Delete empty line

# %%
print()

# %% [markdown]
# # Keep empty cell

# %% [markdown]
# # Ignore cell with Python syntax error

# %%
# %load_ext autoreload
# %autoreload 2

# %%
print(
