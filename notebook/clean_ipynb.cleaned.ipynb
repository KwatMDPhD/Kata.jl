# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

import numpy
import pandas

# %%
sys.path.insert(0, "..")

# %%
print(0)

print(1)


print(2)


print(3)

# %%
from clean_ipynb.clean_ipynb import clean_ipynb

clean_ipynb("clean_ipynb.ipynb", True, False)
